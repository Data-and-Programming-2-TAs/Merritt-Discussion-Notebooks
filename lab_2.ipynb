# %% [markdown]
# # Cleaning Messy Data
#
# We will be working with the Bertelsmann Transformation Index from 2020. It's messy. Let's get into it. The data is from [this site](https://www.bti-project.org/en/meta/downloads.html). If you look at it in Excel, it makes a good bit of sense, but trying to interact with it in an automated manner doesn't work as well.
#
# ## Reading in and Initial Cleaning

# %%
import pandas as pd
from pathlib import Path

file_path = Path.cwd() / 'data' / 'bti.xlsx'
df = pd.read_excel(file_path)

df.head()
# Out:
#   Regions:\n1 | East-Central and Southeast Europe\n2 | Latin America and the Caribbean\n3 | West and Central Africa\n4 | Middle East and North Africa\n5 | Southern and Eastern Africa\n6 | Post-Soviet Eurasia\n7 | Asia and Oceania  \
# 0                                        Afghanistan
# 1                                            Albania
# 2                                            Algeria
# 3                                             Angola
# 4                                          Argentina
#
#      Region    Ranking Status Index    S | Status Index  \
# 0         7                     123            3.213095
# 1         1                      28            6.842857
# 2         4                      83            5.028571
# 3         5                     105            4.164286
# 4         2                      19            7.289286
#
#      Ranking Democracy Status    SI | Democracy Status    Q1 | Stateness  \
# 0                         118                 3.283333              4.00
# 1                          33                 7.150000              9.00
# 2                          80                 4.700000              7.50
# 3                          84                 4.650000              7.25
# 4                          16                 8.150000              9.00
#
#      Q1.1 | Monopoly on the use of force    Q1.2 | State identity  \
# 0                                      2                        7
# 1                                     10                        9
# 2                                      8                        8
# 3                                      8                        7
# 4                                      8                       10
#
#      Q1.3 | No interference of religious dogmas  ...            .2  \
# 0                                             3  ...  Very limited
# 1                                            10  ...       Limited
# 2                                             6  ...       Limited
# 3                                            10  ...  Very limited
# 4                                            10  ...       Limited
#
#      G | Governance Index.1    Category.3        .3  \
# 0                      4.36             3  Moderate
# 1                      5.95             2      Good
# 2                      4.42             3  Moderate
# 3                      4.23             4      Weak
# 4                      6.10             2      Good
#
#      Q13 | Level of Difficulty.1    Category.4        .4  \
# 0                            8.9             1   Massive
# 1                            4.5             3  Moderate
# 2                            5.4             3  Moderate
# 3                            5.9             3  Moderate
# 4                            2.8             4     Minor
#
#      GII | Governance Performance.1    Category.5      .5
# 0                          4.466667             4  Flawed
# 1                          6.783333             2   Sound
# 2                          4.933333             4  Flawed
# 3                          4.650000             4  Flawed
# 4                          7.266667             2   Sound
#
# [5 rows x 125 columns]

# %% [markdown]
# There are some obvious issues here with the columns. The BTI is made up of a number of sections and subquestions and the columns reflect that, but for our purposes that's immaterial. Let's get rid of the stuff before the pipe in the columns. Along the way I'm also getting rid of the whitespace before and after some of the column names.

# %%
df.columns = [c.split('|')[1].strip() if '|' in c else c.strip() for c in df.columns]
print(df.columns.tolist())
# Out:
# ['East-Central and Southeast Europe\n2', 'Region', 'Ranking Status Index', 'Status Index', 'Ranking Democracy Status', 'Democracy Status', 'Stateness', 'Monopoly on the use of force', 'State identity', 'No interference of religious dogmas', 'Basic administration', 'Political Participation', 'Free and fair elections', 'Effective power to govern', 'Association / assembly rights', 'Freedom of expression', 'Rule of Law', 'Separation of powers', 'Independent judiciary', 'Prosecution of office abuse', 'Civil rights', 'Stability of Democratic Institutions', 'Performance of democratic institutions', 'Commitment to democratic institutions', 'Political and Social Integration', 'Party system', 'Interest groups', 'Approval of democracy', 'Social capital', 'Ranking Economy Status', 'Economy Status', 'Level of Socioeconomic Development', 'Socioeconomic barriers', 'Organization of the Market and Competition', 'Market organization', 'Competition policy', 'Liberalization of foreign trade', 'Banking system', 'Monetary and Fiscal Stability', 'Monetary stability', 'Fiscal stability', 'Private Property', 'Property rights', 'Private enterprise', 'Welfare Regime', 'Social safety nets', 'Equal opportunity', 'Economic Performance', 'Output strength', 'Sustainability', 'Environmental policy', 'Education / R&D policy', 'Ranking Governance Index', 'Governance Index', 'Level of Difficulty', 'Structural constraints', 'Civil society traditions', 'Conflict intensity', 'GNI p.c. Atlas method rescaled', 'UN Educ. Index rescaled', 'BTI Stateness & Rule of Law', 'Governance Performance', 'Steering Capability', 'Prioritization', 'Implementation', 'Policy learning', 'Resource Efficiency', 'Efficient use of assets', 'Policy coordination', 'Anti-corruption policy', 'Consensus-Building', 'Consensus on goals', 'Anti-democratic actors', 'Cleavage / conflict management', 'Civil society participation', 'Reconciliation', 'International Cooperation', 'Effective use of support', 'Credibility', 'Regional cooperation', 'Unnamed: 80', 'Trend', 'Democracy Status 18', 'Democracy Status 20', 'Trend Democracy', 'Unnamed: 85', 'Economy Status 18', 'Economy Status 20', 'Trend Economy', 'Unnamed: 89', 'Governance Index 18', 'Governance Index 20', 'Trend Governance', 'Unnamed: 93', 'Unnamed: 94', 'Political System', 'Free and fair elections', 'Effective power to govern', 'Association / assembly rights', 'Freedom of expression', 'Separation of powers', 'Civil rights', 'State failure', 'Total', 'Democracy/Autocracy', 'Unnamed: 105', 'Categories', 'Status Index.1', 'Category', '', 'Democracy Status.1', 'Category.1', '.1', 'Economy Status.1', 'Category.2', '.2', 'Governance Index.1', 'Category.3', '.3', 'Level of Difficulty.1', 'Category.4', '.4', 'Governance Performance.1', 'Category.5', '.5']

# %% [markdown]
# We can see that there are also some unnamed columns and trailing crud still in there. Let's try creating a function to take care of this. You also could do the same thing with a dictionary and the rename function in Pandas.
#
# I'm also going to drop some of the last columns because I don't need them.

# %%
df = df.drop(['Total', 'Trend', 'Categories', 'Political System', 'Trend Governance', 'Region'], axis = 1)
df = df.drop(df.columns[df.columns.str.contains('^Unnamed', case = False)], axis = 1)
df = df.drop(df.columns[df.columns.str.contains('^Category', case = False)], axis = 1)

# %%
def fix_bti_cols(col):
    if col.endswith('\n2'):
        return 'Country'
    if col == '':
        return 'Status Index Description'
    if col == '.1':
        return 'Democracy Status Description'
    if col == '.2':
        return 'Economy Status Description'
    if col == '.3':
        return 'Governance Index Description'
    if col == '.4':
        return 'Level of Difficulty Description'
    if col == '.5':
        return 'Governance Performance Description'
    if col.endswith('.1'):
        return col.strip('.1')
    return col
    
df.columns = [fix_bti_cols(c) for c in df.columns.tolist()]
print(df.columns.tolist())
# Out:
# ['Country', 'Ranking Status Index', 'Status Index', 'Ranking Democracy Status', 'Democracy Status', 'Stateness', 'Monopoly on the use of force', 'State identity', 'No interference of religious dogmas', 'Basic administration', 'Political Participation', 'Free and fair elections', 'Effective power to govern', 'Association / assembly rights', 'Freedom of expression', 'Rule of Law', 'Separation of powers', 'Independent judiciary', 'Prosecution of office abuse', 'Civil rights', 'Stability of Democratic Institutions', 'Performance of democratic institutions', 'Commitment to democratic institutions', 'Political and Social Integration', 'Party system', 'Interest groups', 'Approval of democracy', 'Social capital', 'Ranking Economy Status', 'Economy Status', 'Level of Socioeconomic Development', 'Socioeconomic barriers', 'Organization of the Market and Competition', 'Market organization', 'Competition policy', 'Liberalization of foreign trade', 'Banking system', 'Monetary and Fiscal Stability', 'Monetary stability', 'Fiscal stability', 'Private Property', 'Property rights', 'Private enterprise', 'Welfare Regime', 'Social safety nets', 'Equal opportunity', 'Economic Performance', 'Output strength', 'Sustainability', 'Environmental policy', 'Education / R&D policy', 'Ranking Governance Index', 'Governance Index', 'Level of Difficulty', 'Structural constraints', 'Civil society traditions', 'Conflict intensity', 'GNI p.c. Atlas method rescaled', 'UN Educ. Index rescaled', 'BTI Stateness & Rule of Law', 'Governance Performance', 'Steering Capability', 'Prioritization', 'Implementation', 'Policy learning', 'Resource Efficiency', 'Efficient use of assets', 'Policy coordination', 'Anti-corruption policy', 'Consensus-Building', 'Consensus on goals', 'Anti-democratic actors', 'Cleavage / conflict management', 'Civil society participation', 'Reconciliation', 'International Cooperation', 'Effective use of support', 'Credibility', 'Regional cooperation', 'Democracy Status 18', 'Democracy Status 20', 'Trend Democracy', 'Economy Status 18', 'Economy Status 20', 'Trend Economy', 'Governance Index 18', 'Governance Index 20', 'Free and fair elections', 'Effective power to govern', 'Association / assembly rights', 'Freedom of expression', 'Separation of powers', 'Civil rights', 'State failure', 'Democracy/Autocracy', 'Status Index', 'Status Index Description', 'Democracy Status', 'Democracy Status Description', 'Economy Status', 'Economy Status Description', 'Governance Index', 'Governance Index Description', 'Level of Difficulty', 'Level of Difficulty Description', 'Governance Performance', 'Governance Performance Description']

# %% [markdown]
# Ok, now the columns look decent. Let's make the index be the current Country column.

# %%
df = df.set_index('Country')
# Out:
# <bound method NDFrame.head of              Ranking Status Index  Status Index  Ranking Democracy Status  \
# Country
# Afghanistan                   123      3.213095                       118
# Albania                        28      6.842857                        33
# Algeria                        83      5.028571                        80
# Angola                        105      4.164286                        84
# Argentina                      19      7.289286                        16
# ...                           ...           ...                       ...
# Venezuela                     128      2.773810                       120
# Vietnam                        90      4.819048                       107
# Yemen                         136      1.517857                       136
# Zambia                         76      5.160714                        68
# Zimbabwe                      115      3.683333                        89
#
#              Democracy Status  Stateness  Monopoly on the use of force  \
# Country
# Afghanistan          3.283333       4.00                             2
# Albania              7.150000       9.00                            10
# Algeria              4.700000       7.50                             8
# Angola               4.650000       7.25                             8
# Argentina            8.150000       9.00                             8
# ...                       ...        ...                           ...
# Venezuela            3.083333       6.50                             4
# Vietnam              3.566667       8.75                             9
# Yemen                1.500000       2.00                             1
# Zambia               5.750000       7.75                             9
# Zimbabwe             4.366667       7.75                             9
#
#              State identity  No interference of religious dogmas  \
# Country
# Afghanistan               7                                    3
# Albania                   9                                   10
# Algeria                   8                                    6
# Angola                    7                                   10
# Argentina                10                                   10
# ...                     ...                                  ...
# Venezuela                 9                                   10
# Vietnam                   9                                   10
# Yemen                     2                                    3
# Zambia                    8                                    8
# Zimbabwe                  8                                    9
#
#              Basic administration  Political Participation  ...  \
# Country                                                     ...
# Afghanistan                     4                     3.75  ...
# Albania                         7                     7.75  ...
# Algeria                         8                     4.25  ...
# Angola                          4                     4.25  ...
# Argentina                       8                     9.00  ...
# ...                           ...                      ...  ...
# Venezuela                       3                     2.50  ...
# Vietnam                         7                     2.25  ...
# Yemen                           2                     1.25  ...
# Zambia                          6                     5.50  ...
# Zimbabwe                        5                     3.50  ...
#
#              Democracy Status  Democracy Status Description  Economy Status  \
# Country
# Afghanistan              3.28           Hard-line autocracy            3.14
# Albania                  7.15           Defective democracy            6.54
# Algeria                  4.70            Moderate autocracy            5.36
# Angola                   4.65            Moderate autocracy            3.68
# Argentina                8.15    Democracy in consolidation            6.43
# ...                       ...                           ...             ...
# Venezuela                3.08           Hard-line autocracy            2.46
# Vietnam                  3.57           Hard-line autocracy            6.07
# Yemen                    1.50           Hard-line autocracy            1.54
# Zambia                   5.75    Highly defective democracy            4.57
# Zimbabwe                 4.37            Moderate autocracy            3.00
#
#              Economy Status Description  Governance Index  \
# Country
# Afghanistan                Very limited              4.36
# Albania                         Limited              5.95
# Algeria                         Limited              4.42
# Angola                     Very limited              4.23
# Argentina                       Limited              6.10
# ...                                 ...               ...
# Venezuela                   Rudimentary              1.28
# Vietnam                         Limited              4.73
# Yemen                       Rudimentary              1.63
# Zambia                     Very limited              4.48
# Zimbabwe                   Very limited              3.19
#
#              Governance Index Description  Level of Difficulty  \
# Country
# Afghanistan                      Moderate                  8.9
# Albania                              Good                  4.5
# Algeria                          Moderate                  5.4
# Angola                               Weak                  5.9
# Argentina                            Good                  2.8
# ...                                   ...                  ...
# Venezuela                          Failed                  4.6
# Vietnam                          Moderate                  5.5
# Yemen                              Failed                  9.1
# Zambia                           Moderate                  5.8
# Zimbabwe                             Weak                  6.3
#
#              Level of Difficulty Description  Governance Performance  \
# Country
# Afghanistan                          Massive                4.466667
# Albania                             Moderate                6.783333
# Algeria                             Moderate                4.933333
# Angola                              Moderate                4.650000
# Argentina                              Minor                7.266667
# ...                                      ...                     ...
# Venezuela                           Moderate                1.458333
# Vietnam                             Moderate                5.250000
# Yemen                                Massive                1.666667
# Zambia                              Moderate                4.937500
# Zimbabwe                            Moderate                3.483333
#
#              Governance Performance Description
# Country
# Afghanistan                              Flawed
# Albania                                   Sound
# Algeria                                  Flawed
# Angola                                   Flawed
# Argentina                                 Sound
# ...                                         ...
# Venezuela                                  Poor
# Vietnam                                    Fair
# Yemen                                      Poor
# Zambia                                   Flawed
# Zimbabwe                                 Flawed
#
# [137 rows x 106 columns]>

# %%
df.head()
# Out:
#              Ranking Status Index  Status Index  Ranking Democracy Status  \
# Country
# Afghanistan                   123      3.213095                       118
# Albania                        28      6.842857                        33
# Algeria                        83      5.028571                        80
# Angola                        105      4.164286                        84
# Argentina                      19      7.289286                        16
#
#              Democracy Status  Stateness  Monopoly on the use of force  \
# Country
# Afghanistan          3.283333       4.00                             2
# Albania              7.150000       9.00                            10
# Algeria              4.700000       7.50                             8
# Angola               4.650000       7.25                             8
# Argentina            8.150000       9.00                             8
#
#              State identity  No interference of religious dogmas  \
# Country
# Afghanistan               7                                    3
# Albania                   9                                   10
# Algeria                   8                                    6
# Angola                    7                                   10
# Argentina                10                                   10
#
#              Basic administration  Political Participation  ...  \
# Country                                                     ...
# Afghanistan                     4                     3.75  ...
# Albania                         7                     7.75  ...
# Algeria                         8                     4.25  ...
# Angola                          4                     4.25  ...
# Argentina                       8                     9.00  ...
#
#              Democracy Status  Democracy Status Description  Economy Status  \
# Country
# Afghanistan              3.28           Hard-line autocracy            3.14
# Albania                  7.15           Defective democracy            6.54
# Algeria                  4.70            Moderate autocracy            5.36
# Angola                   4.65            Moderate autocracy            3.68
# Argentina                8.15    Democracy in consolidation            6.43
#
#              Economy Status Description  Governance Index  \
# Country
# Afghanistan                Very limited              4.36
# Albania                         Limited              5.95
# Algeria                         Limited              4.42
# Angola                     Very limited              4.23
# Argentina                       Limited              6.10
#
#              Governance Index Description  Level of Difficulty  \
# Country
# Afghanistan                      Moderate                  8.9
# Albania                              Good                  4.5
# Algeria                          Moderate                  5.4
# Angola                               Weak                  5.9
# Argentina                            Good                  2.8
#
#              Level of Difficulty Description  Governance Performance  \
# Country
# Afghanistan                          Massive                4.466667
# Albania                             Moderate                6.783333
# Algeria                             Moderate                4.933333
# Angola                              Moderate                4.650000
# Argentina                              Minor                7.266667
#
#              Governance Performance Description
# Country
# Afghanistan                              Flawed
# Albania                                   Sound
# Algeria                                  Flawed
# Angola                                   Flawed
# Argentina                                 Sound
#
# [5 rows x 106 columns]

# %%
print(df.loc['Afghanistan'].tolist())
# Out:
# [123, 3.2130952380952382, 118, 3.2833333333333337, 4.0, 2, 7, 3, 4, 3.75, 4, 2, 5, 4, 3.0, 4, 3, 3, 2, 3.0, 3, 3, 2.6666666666666665, 3, 3, nan, 2, 122, 3.142857142857143, 1, 1, 4.0, 4, 4, 4, 4, 4.5, 5, 4, 3.5, 2, 5, 2.5, 2, 3, 4, 4, 2.5, 3, 2, 89, 4.359135802469137, 8.916666666666666, 10, 10, 9, 9, 8, 7.5, 4.466666666666667, 4.666666666666667, 5, 4, 5, 3.0, 3, 3, 3, 4.2, 3, 4, 5, 4, 5.0, 6.0, 6, 5, 7, 3.0166666666666666, 3.2833333333333337, 0.26666666666666705, 2.892857142857143, 3.142857142857143, 0.25, 4.023279320987655, 4.359135802469137, 4, 2, 5, 4, 4, 2, 3.0, 'Aut.', 3.21, 'Failed', 3.28, 'Hard-line autocracy', 3.14, 'Very limited', 4.36, 'Moderate', 8.9, 'Massive', 4.466666666666667, 'Flawed']

# %% [markdown]
# No NaNs! So our work is done.
